# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
from tqdm import tqdm
import sklearn

# %%
print(sklearn.__version__)
# Out:
# 0.24.1

# %%
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
tf.config.experimental.set_visible_devices(devices=gpus[0], device_type='GPU')
tf.config.experimental.set_memory_growth(device=gpus[0], enable=True)

# %%
data = pd.read_csv('stoch_corr_tanh_rho_1000.csv', header=None)

# %%
observations = data.iloc[:100000, 1:1000]
paramsets = data.iloc[:100000, 1003:1004]

# %%
params_reshape = np.array(paramsets).reshape(100000, 1, 1)
one_sample_reshape = np.array(observations).reshape(100000,1,999)

# %%
print(params_reshape.shape, one_sample_reshape.shape)
# Out:
# (100000, 1, 1) (100000, 1, 999)

# %%
tf.keras.backend.clear_session()
tf.keras.backend.set_floatx('float64')

model = tf.keras.Sequential()
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.elu, input_shape=(1, 999)))
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.elu))
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.elu))
model.add(layer=tf.keras.layers.Dense(units=1, activation=tf.keras.activations.sigmoid))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1, 30)             30000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 30)             930
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 30)             930
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 1)              31
# =================================================================
# Total params: 31,891
# Trainable params: 31,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.mse,
)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=2)

history = model.fit(x=one_sample_reshape, y=params_reshape, epochs=100, validation_split=0.20, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 2500/2500 [==============================] - 16s 6ms/step - loss: 0.0047 - val_loss: 6.6278e-04
# Epoch 2/100
# 2500/2500 [==============================] - 24s 10ms/step - loss: 2.9408e-04 - val_loss: 8.1701e-05
# Epoch 3/100
# 2500/2500 [==============================] - 26s 10ms/step - loss: 8.3160e-05 - val_loss: 8.0082e-05
# Epoch 4/100
# 2500/2500 [==============================] - 26s 10ms/step - loss: 7.9030e-05 - val_loss: 8.2664e-05
# Epoch 5/100
# 2500/2500 [==============================] - 25s 10ms/step - loss: 7.8110e-05 - val_loss: 7.5607e-05
# Epoch 6/100
# 2500/2500 [==============================] - 26s 10ms/step - loss: 7.5775e-05 - val_loss: 8.2635e-05
# Epoch 7/100
# 2500/2500 [==============================] - 25s 10ms/step - loss: 7.4445e-05 - val_loss: 7.7595e-05
# Epoch 8/100
# 2500/2500 [==============================] - 27s 11ms/step - loss: 7.2447e-05 - val_loss: 7.8172e-05
# Epoch 9/100
# 2500/2500 [==============================] - 25s 10ms/step - loss: 7.0584e-05 - val_loss: 7.9134e-05
# Epoch 10/100
# 2500/2500 [==============================] - 27s 11ms/step - loss: 6.8757e-05 - val_loss: 8.0451e-05
# Epoch 11/100
# 2500/2500 [==============================] - 25s 10ms/step - loss: 6.7740e-05 - val_loss: 7.7967e-05
# Epoch 12/100
# 2500/2500 [==============================] - 27s 11ms/step - loss: 6.6373e-05 - val_loss: 8.0552e-05
# Epoch 13/100
# 2500/2500 [==============================] - 25s 10ms/step - loss: 6.5430e-05 - val_loss: 8.5805e-05
# Epoch 14/100
# 2500/2500 [==============================] - 27s 11ms/step - loss: 6.4757e-05 - val_loss: 7.9971e-05
# Epoch 15/100
# 2500/2500 [==============================] - 25s 10ms/step - loss: 6.4110e-05 - val_loss: 7.9468e-05
# Epoch 16/100
# 2500/2500 [==============================] - 26s 10ms/step - loss: 6.2950e-05 - val_loss: 8.1024e-05
# Epoch 17/100
# 2500/2500 [==============================] - 25s 10ms/step - loss: 6.2521e-05 - val_loss: 7.9864e-05
# Epoch 18/100
# 2500/2500 [==============================] - 26s 10ms/step - loss: 6.1413e-05 - val_loss: 8.2156e-05
# Epoch 19/100
# 2500/2500 [==============================] - 25s 10ms/step - loss: 6.0577e-05 - val_loss: 8.2790e-05
# Epoch 20/100
# 2500/2500 [==============================] - 20s 8ms/step - loss: 6.0393e-05 - val_loss: 8.2248e-05
# Epoch 21/100
# 2500/2500 [==============================] - 19s 8ms/step - loss: 5.9668e-05 - val_loss: 8.3031e-05
# Epoch 22/100
# 2500/2500 [==============================] - 20s 8ms/step - loss: 5.9138e-05 - val_loss: 8.3094e-05
# Epoch 23/100
# 2500/2500 [==============================] - 18s 7ms/step - loss: 5.8969e-05 - val_loss: 8.4641e-05
# Epoch 24/100
# 2500/2500 [==============================] - 18s 7ms/step - loss: 5.7936e-05 - val_loss: 8.3974e-05
# Epoch 25/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 5.7802e-05 - val_loss: 8.5116e-05
# Epoch 26/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 5.7492e-05 - val_loss: 8.5221e-05
# Epoch 27/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.6594e-05 - val_loss: 8.4750e-05
# Epoch 28/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 5.6463e-05 - val_loss: 8.5278e-05
# Epoch 29/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.6053e-05 - val_loss: 8.7456e-05
# Epoch 30/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.6139e-05 - val_loss: 8.5004e-05
# Epoch 31/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.5264e-05 - val_loss: 8.6747e-05
# Epoch 32/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.5190e-05 - val_loss: 8.5548e-05
# Epoch 33/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.5076e-05 - val_loss: 8.5928e-05
# Epoch 34/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 5.4974e-05 - val_loss: 8.6563e-05
# Epoch 35/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.4480e-05 - val_loss: 8.5318e-05
# Epoch 36/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.3697e-05 - val_loss: 8.7070e-05
# Epoch 37/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.3709e-05 - val_loss: 8.7597e-05
# Epoch 38/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.3242e-05 - val_loss: 8.9621e-05
# Epoch 39/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.2977e-05 - val_loss: 9.1084e-05
# Epoch 40/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.3098e-05 - val_loss: 8.8474e-05
# Epoch 41/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.2478e-05 - val_loss: 8.9165e-05
# Epoch 42/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.2161e-05 - val_loss: 8.7380e-05
# Epoch 43/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.2062e-05 - val_loss: 8.8779e-05
# Epoch 44/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 5.2015e-05 - val_loss: 9.0979e-05
# Epoch 45/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.1521e-05 - val_loss: 9.2260e-05
# Epoch 46/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 5.1743e-05 - val_loss: 8.9565e-05
# Epoch 47/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.1545e-05 - val_loss: 9.6094e-05
# Epoch 48/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.1381e-05 - val_loss: 9.0674e-05
# Epoch 49/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.1292e-05 - val_loss: 9.2394e-05
# Epoch 50/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 5.0548e-05 - val_loss: 8.9162e-05
# Epoch 51/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.1291e-05 - val_loss: 9.0804e-05
# Epoch 52/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 5.1297e-05 - val_loss: 8.9674e-05
# Epoch 53/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.0267e-05 - val_loss: 9.0749e-05
# Epoch 54/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.9824e-05 - val_loss: 9.1167e-05
# Epoch 55/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 5.0181e-05 - val_loss: 9.2456e-05
# Epoch 56/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.9674e-05 - val_loss: 9.1733e-05
# Epoch 57/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.9375e-05 - val_loss: 9.2791e-05
# Epoch 58/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.9092e-05 - val_loss: 9.3380e-05
# Epoch 59/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.9018e-05 - val_loss: 9.2133e-05
# Epoch 60/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.9350e-05 - val_loss: 9.3560e-05
# Epoch 61/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.8923e-05 - val_loss: 9.3531e-05
# Epoch 62/100
# 2500/2500 [==============================] - 11s 5ms/step - loss: 4.8733e-05 - val_loss: 9.7280e-05
# Epoch 63/100
# 2500/2500 [==============================] - 9s 4ms/step - loss: 4.8820e-05 - val_loss: 9.1372e-05
# Epoch 64/100
# 2500/2500 [==============================] - 9s 4ms/step - loss: 4.8662e-05 - val_loss: 9.3953e-05
# Epoch 65/100
# 2500/2500 [==============================] - 9s 4ms/step - loss: 4.8238e-05 - val_loss: 9.2681e-05
# Epoch 66/100
# 2500/2500 [==============================] - 13s 5ms/step - loss: 4.8486e-05 - val_loss: 9.6555e-05
# Epoch 67/100
# 2500/2500 [==============================] - 10s 4ms/step - loss: 4.8168e-05 - val_loss: 9.4465e-05
# Epoch 68/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.8260e-05 - val_loss: 9.7322e-05
# Epoch 69/100
# 2500/2500 [==============================] - 10s 4ms/step - loss: 4.7998e-05 - val_loss: 9.5435e-05
# Epoch 70/100
# 2500/2500 [==============================] - 11s 5ms/step - loss: 4.7664e-05 - val_loss: 9.5444e-05
# Epoch 71/100
# 2500/2500 [==============================] - 10s 4ms/step - loss: 4.7799e-05 - val_loss: 9.4811e-05
# Epoch 72/100
# 2500/2500 [==============================] - 10s 4ms/step - loss: 4.7501e-05 - val_loss: 9.6706e-05
# Epoch 73/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.7748e-05 - val_loss: 9.3606e-05
# Epoch 74/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.7452e-05 - val_loss: 9.5461e-05
# Epoch 75/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.7524e-05 - val_loss: 9.6123e-05
# Epoch 76/100
# 2500/2500 [==============================] - 11s 5ms/step - loss: 4.7526e-05 - val_loss: 9.9290e-05
# Epoch 77/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.7114e-05 - val_loss: 9.5990e-05
# Epoch 78/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.7274e-05 - val_loss: 9.5460e-05
# Epoch 79/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.6924e-05 - val_loss: 9.6696e-05
# Epoch 80/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.7308e-05 - val_loss: 9.6413e-05
# Epoch 81/100
# 2500/2500 [==============================] - 11s 5ms/step - loss: 4.6978e-05 - val_loss: 9.5899e-05
# Epoch 82/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.7062e-05 - val_loss: 9.5005e-05
# Epoch 83/100
# 2500/2500 [==============================] - 11s 5ms/step - loss: 4.6417e-05 - val_loss: 9.6165e-05
# Epoch 84/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.6099e-05 - val_loss: 9.7361e-05
# Epoch 85/100
# 2500/2500 [==============================] - 10s 4ms/step - loss: 4.6763e-05 - val_loss: 9.9474e-05
# Epoch 86/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.6791e-05 - val_loss: 1.0048e-04
# Epoch 87/100
# 2500/2500 [==============================] - 10s 4ms/step - loss: 4.6168e-05 - val_loss: 9.6367e-05
# Epoch 88/100
# 2500/2500 [==============================] - 15s 6ms/step - loss: 4.5724e-05 - val_loss: 9.8629e-05
# Epoch 89/100
# 2500/2500 [==============================] - 14s 6ms/step - loss: 4.6478e-05 - val_loss: 9.8614e-05
# Epoch 90/100
# 2500/2500 [==============================] - 16s 7ms/step - loss: 4.5637e-05 - val_loss: 9.6606e-05
# Epoch 91/100
# 2500/2500 [==============================] - 15s 6ms/step - loss: 4.6292e-05 - val_loss: 1.0059e-04
# Epoch 92/100
# 2500/2500 [==============================] - 16s 6ms/step - loss: 4.6156e-05 - val_loss: 9.7606e-05
# Epoch 93/100
# 2500/2500 [==============================] - 14s 6ms/step - loss: 4.5947e-05 - val_loss: 1.0056e-04
# Epoch 94/100
# 2500/2500 [==============================] - 14s 6ms/step - loss: 4.5590e-05 - val_loss: 9.6655e-05
# Epoch 95/100
# 2500/2500 [==============================] - 10s 4ms/step - loss: 4.5831e-05 - val_loss: 1.0132e-04
# Epoch 96/100
# 2500/2500 [==============================] - 9s 4ms/step - loss: 4.5407e-05 - val_loss: 9.8274e-05
# Epoch 97/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.5748e-05 - val_loss: 1.0108e-04
# Epoch 98/100
# 2500/2500 [==============================] - 11s 4ms/step - loss: 4.5587e-05 - val_loss: 1.0259e-04
# Epoch 99/100
# 2500/2500 [==============================] - 10s 4ms/step - loss: 4.5712e-05 - val_loss: 1.0131e-04
# Epoch 100/100
# 2500/2500 [==============================] - 12s 5ms/step - loss: 4.5603e-05 - val_loss: 9.9638e-05

# %%
simulated = []
predicted = []

append_index = 0
start = 90000

for i in tqdm(range(start, start + 500, 1)):
    test_input = one_sample_reshape[i]
    test_input_1 = test_input.reshape(1, 1, 999)
    test_output = model.predict(test_input_1, verbose=0)
    # if np.linalg.norm(params_reshape[i][0][0]-test_output[0][0]) <= 0.005:
        # append_index = append_index + 1
        # print(f'appended: {append_index}')
    predicted.append(test_output[0][0]) 
    simulated.append(params_reshape[i][0][0])
    # else:
    #     None
    
    # print(test_output, params_reshape[i])
# Out:
# 100%|██████████| 500/500 [00:29<00:00, 17.14it/s]

# %%
plt.figure(figsize=(16,8))
plt.plot([0.02,0.05], [0.02,0.05], 'red')
plt.scatter(simulated, predicted)
plt.xlabel('Hurst simulated')
plt.ylabel('Hurst predicted')
plt.title('Dense Hurst prediction tanh(X)')
plt.show()

# %%
simulated = []
predicted = []

append_index = 0
start = 10000

for i in tqdm(range(start, start + 500, 1)):
    test_input = one_sample_reshape[i]
    test_input_1 = test_input.reshape(1, 1, 999)
    test_output = model.predict(test_input_1, verbose=0)
    # if np.linalg.norm(params_reshape[i][0][0]-test_output[0][0]) <= 0.005:
        # append_index = append_index + 1
        # print(f'appended: {append_index}')
    predicted.append(test_output[0][0]) 
    simulated.append(params_reshape[i][0][0])
    # else:
    #     None
    
    # print(test_output, params_reshape[i])
# Out:
# 100%|██████████| 500/500 [00:26<00:00, 18.71it/s]

# %%
plt.figure(figsize=(16,8))
plt.plot([0.02,0.05], [0.02,0.05], 'red')
plt.scatter(simulated, predicted)
plt.xlabel('Hurst simulated')
plt.ylabel('Hurst predicted')
plt.title('Dense Hurst prediction tanh(X)')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Dense Hurst prediction tanh(X)')
plt.legend(['loss', 'val_loss'])
plt.show()

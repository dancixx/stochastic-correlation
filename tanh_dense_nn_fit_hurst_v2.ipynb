# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
from tqdm import tqdm
import sklearn

# %%
print(sklearn.__version__)
# Out:
# 0.24.1

# %%
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
tf.config.experimental.set_visible_devices(devices=gpus[0], device_type='GPU')
tf.config.experimental.set_memory_growth(device=gpus[0], enable=True)

# %%
data = pd.read_csv('stoch_corr_tanh_1000_v2.csv', header=None)
# Out:
# C:\Users\danci\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
observations = data.iloc[:100000, 1:1000]
paramsets = data.iloc[:100000, 1003:1004]

# %%
params_reshape = np.array(paramsets).reshape(100000, 1, 1)
one_sample_reshape = np.array(observations).reshape(100000,1,999)

# %%
print(params_reshape.shape, one_sample_reshape.shape)
# Out:
# (100000, 1, 1) (100000, 1, 999)

# %%
tf.keras.backend.clear_session()
tf.keras.backend.set_floatx('float64')

model = tf.keras.Sequential()
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.elu, input_shape=(1, 999)))
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.elu))
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.elu))
model.add(layer=tf.keras.layers.Dense(units=1, activation=tf.keras.activations.elu))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1, 30)             30000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 30)             930
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 30)             930
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 1)              31
# =================================================================
# Total params: 31,891
# Trainable params: 31,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.mse,
)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=2)

history = model.fit(x=one_sample_reshape, y=params_reshape, epochs=100, validation_split=0.2, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.0131 - val_loss: 2.3509e-04
# Epoch 2/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 2.1501e-04 - val_loss: 1.4999e-04
# Epoch 3/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.6060e-04 - val_loss: 1.3164e-04
# Epoch 4/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.3330e-04 - val_loss: 1.2418e-04
# Epoch 5/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.1699e-04 - val_loss: 9.9819e-05
# Epoch 6/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.0336e-04 - val_loss: 1.0189e-04
# Epoch 7/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 9.5097e-05 - val_loss: 9.8111e-05
# Epoch 8/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 9.4879e-05 - val_loss: 9.6524e-05
# Epoch 9/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 9.3292e-05 - val_loss: 8.1762e-05
# Epoch 10/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 8.4426e-05 - val_loss: 9.8883e-05
# Epoch 11/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 8.5707e-05 - val_loss: 8.0281e-05
# Epoch 12/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 8.9771e-05 - val_loss: 1.0154e-04
# Epoch 13/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 8.2777e-05 - val_loss: 8.4132e-05
# Epoch 14/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.0008e-04 - val_loss: 7.7009e-05
# Epoch 15/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 7.7936e-05 - val_loss: 8.0297e-05
# Epoch 16/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 8.0538e-05 - val_loss: 7.8044e-05
# Epoch 17/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 8.0622e-05 - val_loss: 7.7564e-05
# Epoch 18/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 8.0335e-05 - val_loss: 7.7050e-05
# Epoch 19/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7.7750e-05 - val_loss: 7.7838e-05
# Epoch 20/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7.7419e-05 - val_loss: 7.5729e-05
# Epoch 21/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 7.7175e-05 - val_loss: 7.5495e-05
# Epoch 22/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7.7046e-05 - val_loss: 7.7967e-05
# Epoch 23/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7.6791e-05 - val_loss: 7.6333e-05
# Epoch 24/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7.6122e-05 - val_loss: 7.5034e-05
# Epoch 25/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7.6329e-05 - val_loss: 7.8233e-05
# Epoch 26/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7.6096e-05 - val_loss: 7.5332e-05
# Epoch 27/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7.6258e-05 - val_loss: 7.5698e-05
# Epoch 28/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 7
100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 6.1720e-05 - val_loss: 8.5204e-05
# Epoch 75/100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 6.2338e-05 - val_loss: 8.4512e-05
# Epoch 76/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.1656e-05 - val_loss: 8.4434e-05
# Epoch 77/100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 6.1938e-05 - val_loss: 8.4976e-05
# Epoch 78/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.1594e-05 - val_loss: 8.8230e-05
# Epoch 79/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.1113e-05 - val_loss: 8.8162e-05
# Epoch 80/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.0910e-05 - val_loss: 8.6991e-05
# Epoch 81/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.0773e-05 - val_loss: 8.4261e-05
# Epoch 82/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.0629e-05 - val_loss: 8.7690e-05
# Epoch 83/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.0757e-05 - val_loss: 8.9547e-05
# Epoch 84/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.0124e-05 - val_loss: 8.8049e-05
# Epoch 85/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 6.0029e-05 - val_loss: 9.2996e-05
# Epoch 86/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.9134e-05 - val_loss: 8.8800e-05
# Epoch 87/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.9473e-05 - val_loss: 8.7740e-05
# Epoch 88/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.8773e-05 - val_loss: 8.6971e-05
# Epoch 89/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.9121e-05 - val_loss: 8.8592e-05
# Epoch 90/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.9093e-05 - val_loss: 8.6946e-05
# Epoch 91/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.8208e-05 - val_loss: 9.0471e-05
# Epoch 92/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.8066e-05 - val_loss: 8.7707e-05
# Epoch 93/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.8263e-05 - val_loss: 8.9236e-05
# Epoch 94/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.7781e-05 - val_loss: 8.9937e-05
# Epoch 95/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.7852e-05 - val_loss: 8.9912e-05
# Epoch 96/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.7206e-05 - val_loss: 8.8295e-05
# Epoch 97/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.7126e-05 - val_loss: 8.8998e-05
# Epoch 98/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.6982e-05 - val_loss: 9.0160e-05
# Epoch 99/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.7221e-05 - val_loss: 9.1161e-05
# Epoch 100/100
# 1250/1250 [==============================] - 7s 6ms/step - loss: 5.7146e-05 - val_loss: 9.0127e-05

# %%
simulated = []
predicted = []

append_index = 0
start = 90000

for i in tqdm(range(start, start + 500, 1)):
    test_input = one_sample_reshape[i]
    test_input_1 = test_input.reshape(1, 1, 999)
    test_output = model.predict(test_input_1, verbose=0)
    # if np.linalg.norm(params_reshape[i][0][0]-test_output[0][0]) <= 0.005:
        # append_index = append_index + 1
        # print(f'appended: {append_index}')
    predicted.append(test_output[0][0]) 
    simulated.append(params_reshape[i][0][0])
    # else:
    #     None
    
    # print(test_output, params_reshape[i])
# Out:
# 100%|██████████| 500/500 [00:21<00:00, 23.69it/s]

# %%
plt.figure(figsize=(16,8))
plt.plot([0.12,0.15], [0.12,0.15], 'red')
plt.scatter(simulated, predicted)
plt.xlabel('Hurst simulated')
plt.ylabel('Hurst predicted')
plt.title('Dense Hurst prediction tanh(X)')
plt.show()

# %%
append_index = 0
start = 10000

for i in tqdm(range(start, start + 500, 1)):
    test_input = one_sample_reshape[i]
    test_input_1 = test_input.reshape(1, 1, 999)
    test_output = model.predict(test_input_1, verbose=0)
    # if np.linalg.norm(params_reshape[i][0][0]-test_output[0][0]) <= 0.005:
        # append_index = append_index + 1
        # print(f'appended: {append_index}')
    predicted.append(test_output[0][0]) 
    simulated.append(params_reshape[i][0][0])
    # else:
    #     None
    
    # print(test_output, params_reshape[i])
# Out:
# 100%|██████████| 500/500 [00:20<00:00, 24.02it/s]

# %%
plt.figure(figsize=(16,8))
plt.plot([0.12,0.15], [0.12,0.15], 'red')
plt.scatter(simulated, predicted)
plt.xlabel('Hurst simulated')
plt.ylabel('Hurst predicted')
plt.title('Dense Hurst prediction tanh(X)')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

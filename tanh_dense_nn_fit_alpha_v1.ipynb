# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
from tqdm import tqdm
import sklearn

# %%
print(sklearn.__version__)
# Out:
# 0.24.1

# %%
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
tf.config.experimental.set_visible_devices(devices=gpus[0], device_type='GPU')
tf.config.experimental.set_memory_growth(device=gpus[0], enable=True)

# %%
data = pd.read_csv('stoch_corr_tanh_rho_1000.csv', header=None)
# Out:
# C:\Users\danci\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
observations = data.iloc[:100000, 1:1000]
paramsets = data.iloc[:100000, 1000:1001]

# %%
observations.shape
# Out:
# (100000, 999)

# %%
params_reshape = np.array(paramsets).reshape(100000, 1, 1)
one_sample_reshape = np.array(observations).reshape(100000,1,999)

# %%
print(params_reshape.shape, one_sample_reshape.shape)
# Out:
# (100000, 1, 1) (100000, 1, 999)

# %%
tf.keras.backend.clear_session()
tf.keras.backend.set_floatx('float64')

model = tf.keras.Sequential()
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.relu, input_shape=(1, 999)))
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.relu))
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.relu))
model.add(layer=tf.keras.layers.Dense(units=1, activation=tf.keras.activations.relu))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1, 30)             30000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 30)             930
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 30)             930
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 1)              31
# =================================================================
# Total params: 31,891
# Trainable params: 31,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer="adam",
    loss='mse',
)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10)

history = model.fit(x=one_sample_reshape, y=params_reshape, epochs=25, validation_split=0.20, batch_size=32, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/25
# 2500/2500 [==============================] - 11s 4ms/step - loss: 8.3312 - val_loss: 2.5537
# Epoch 2/25
# 2500/2500 [==============================] - 16s 6ms/step - loss: 2.4570 - val_loss: 2.4926
# Epoch 3/25
# 2500/2500 [==============================] - 23s 9ms/step - loss: 2.3616 - val_loss: 2.5011
# Epoch 4/25
# 2500/2500 [==============================] - 26s 11ms/step - loss: 2.3034 - val_loss: 2.4684
# Epoch 5/25
# 2500/2500 [==============================] - 25s 10ms/step - loss: 2.2261 - val_loss: 2.4253
# Epoch 6/25
# 2500/2500 [==============================] - 26s 11ms/step - loss: 2.1921 - val_loss: 2.4094
# Epoch 7/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 2.1488 - val_loss: 2.4429
# Epoch 8/25
# 2500/2500 [==============================] - 25s 10ms/step - loss: 2.0941 - val_loss: 2.3864
# Epoch 9/25
# 2500/2500 [==============================] - 26s 11ms/step - loss: 2.0590 - val_loss: 2.4793
# Epoch 10/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 2.0215 - val_loss: 2.3576
# Epoch 11/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 1.9677 - val_loss: 2.3936
# Epoch 12/25
# 2500/2500 [==============================] - 27s 11ms/step - loss: 1.9172 - val_loss: 2.4099
# Epoch 13/25
# 2500/2500 [==============================] - 25s 10ms/step - loss: 1.8877 - val_loss: 2.5746
# Epoch 14/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 1.8673 - val_loss: 2.4102
# Epoch 15/25
# 2500/2500 [==============================] - 27s 11ms/step - loss: 1.8437 - val_loss: 2.4662
# Epoch 16/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 1.7961 - val_loss: 2.4996
# Epoch 17/25
# 2500/2500 [==============================] - 25s 10ms/step - loss: 1.7605 - val_loss: 2.4226
# Epoch 18/25
# 2500/2500 [==============================] - 25s 10ms/step - loss: 1.7423 - val_loss: 2.5493
# Epoch 19/25
# 2500/2500 [==============================] - 25s 10ms/step - loss: 1.7106 - val_loss: 2.5295
# Epoch 20/25
# 2500/2500 [==============================] - 25s 10ms/step - loss: 1.6718 - val_loss: 2.4792

# %%
simulated = []
predicted = []

append_index = 0
start = 90000

for i in tqdm(range(start, start + 500, 1)):
    test_input = one_sample_reshape[i]
    test_input_1 = test_input.reshape(1, 1, 999)
    test_output = model.predict(test_input_1, verbose=0)
    # if np.linalg.norm(params_reshape[i][0][0]-test_output[0][0]) <= 1.50:
        # append_index = append_index + 1
        # print(f'appended: {append_index}')
    predicted.append(test_output[0][0])
    simulated.append(params_reshape[i][0][0])
    # else:
    #     None
    
    # print(test_output, params_reshape[i])
# Out:
# 100%|██████████| 500/500 [00:24<00:00, 20.06it/s]

# %%
plt.figure(figsize=(16,8))
plt.plot([6,12], [6,12], 'red')
plt.scatter(simulated, predicted)
plt.xlabel('alpha simulated')
plt.ylabel('alpha predicted')
plt.title('Dense alpha prediction tanh(X)')
plt.show()

# %%
simulated = []
predicted = []

append_index = 0
start = 10000

for i in tqdm(range(start, start + 500, 1)):
    test_input = one_sample_reshape[i]
    test_input_1 = test_input.reshape(1, 1, 999)
    test_output = model.predict(test_input_1, verbose=0)
    # if np.linalg.norm(params_reshape[i][0][0]-test_output[0][0]) <= 1.50:
        # append_index = append_index + 1
        # print(f'appended: {append_index}')
    predicted.append(test_output[0][0])
    simulated.append(params_reshape[i][0][0])
    # else:
    #     None
    
    # print(test_output, params_reshape[i])
# Out:
# 100%|██████████| 500/500 [00:24<00:00, 20.39it/s]

# %%
plt.figure(figsize=(16,8))
plt.plot([6,12], [6,12], 'red')
plt.scatter(simulated, predicted)
plt.xlabel('alpha simulated')
plt.ylabel('alpha predicted')
plt.title('Dense alpha prediction tanh(X)')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Dense alpha prediction tanh(X)')
plt.legend(['loss', 'val_loss'])
plt.show()

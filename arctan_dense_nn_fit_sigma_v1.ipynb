# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
from tqdm import tqdm
import sklearn

# %%
print(sklearn.__version__)
# Out:
# 0.24.1

# %%
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
tf.config.experimental.set_visible_devices(devices=gpus[0], device_type='GPU')
tf.config.experimental.set_memory_growth(device=gpus[0], enable=True)

# %%
data = pd.read_csv('stoch_corr_arctan_1000.csv', header=None)
# Out:
# C:\Users\danci\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
observations = data.iloc[:100000, 1:1000]
paramsets = data.iloc[:100000, 1002:1003]

# %%
params_reshape = np.array(paramsets).reshape(100000, 1, 1)
one_sample_reshape = np.array(observations).reshape(100000,1,999)

# %%
print(params_reshape.shape, one_sample_reshape.shape)
# Out:
# (100000, 1, 1) (100000, 1, 999)

# %%
tf.keras.backend.clear_session()
tf.keras.backend.set_floatx('float64')

model = tf.keras.Sequential()
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.relu, input_shape=(1, 999)))
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.relu))
model.add(layer=tf.keras.layers.Dense(units=30, activation=tf.keras.activations.relu))
model.add(layer=tf.keras.layers.Dense(units=1, activation=tf.keras.activations.sigmoid))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1, 30)             30000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 30)             930
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 30)             930
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 1)              31
# =================================================================
# Total params: 31,891
# Trainable params: 31,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer="adam",
    loss='mse',
)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10)

history = model.fit(x=one_sample_reshape, y=params_reshape, epochs=25, validation_split=0.20, batch_size=32, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/25
# 2500/2500 [==============================] - 12s 4ms/step - loss: 0.0329 - val_loss: 0.0198
# Epoch 2/25
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.0154 - val_loss: 0.0135
# Epoch 3/25
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.0117 - val_loss: 0.0126
# Epoch 4/25
# 2500/2500 [==============================] - 16s 6ms/step - loss: 0.0097 - val_loss: 0.0096
# Epoch 5/25
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.0085 - val_loss: 0.0096
# Epoch 6/25
# 2500/2500 [==============================] - 16s 7ms/step - loss: 0.0075 - val_loss: 0.0099
# Epoch 7/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 8/25
# 2500/2500 [==============================] - 35s 14ms/step - loss: 0.0059 - val_loss: 0.0077
# Epoch 9/25
# 2500/2500 [==============================] - 33s 13ms/step - loss: 0.0057 - val_loss: 0.0072
# Epoch 10/25
# 2500/2500 [==============================] - 31s 12ms/step - loss: 0.0050 - val_loss: 0.0074
# Epoch 11/25
# 2500/2500 [==============================] - 27s 11ms/step - loss: 0.0048 - val_loss: 0.0082
# Epoch 12/25
# 2500/2500 [==============================] - 27s 11ms/step - loss: 0.0044 - val_loss: 0.0069
# Epoch 13/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 0.0043 - val_loss: 0.0062
# Epoch 14/25
# 2500/2500 [==============================] - 27s 11ms/step - loss: 0.0040 - val_loss: 0.0069
# Epoch 15/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 0.0038 - val_loss: 0.0060
# Epoch 16/25
# 2500/2500 [==============================] - 27s 11ms/step - loss: 0.0037 - val_loss: 0.0065
# Epoch 17/25
# 2500/2500 [==============================] - 26s 10ms/step - loss: 0.0036 - val_loss: 0.0059
# Epoch 18/25
# 2500/2500 [==============================] - 28s 11ms/step - loss: 0.0034 - val_loss: 0.0068
# Epoch 19/25
# 2500/2500 [==============================] - 26s 11ms/step - loss: 0.0032 - val_loss: 0.0066
# Epoch 20/25
# 2500/2500 [==============================] - 28s 11ms/step - loss: 0.0033 - val_loss: 0.0065
# Epoch 21/25
# 2500/2500 [==============================] - 23s 9ms/step - loss: 0.0032 - val_loss: 0.0079
# Epoch 22/25
# 2500/2500 [==============================] - 25s 10ms/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 23/25
# 2500/2500 [==============================] - 27s 11ms/step - loss: 0.0030 - val_loss: 0.0059
# Epoch 24/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0029 - val_loss: 0.0056
# Epoch 25/25
# 2500/2500 [==============================] - 27s 11ms/step - loss: 0.0027 - val_loss: 0.0063

# %%
simulated = []
predicted = []

append_index = 0
start = 90000

for i in tqdm(range(start, start + 500, 1)):
    test_input = one_sample_reshape[i]
    test_input_1 = test_input.reshape(1, 1, 999)
    test_output = model.predict(test_input_1, verbose=0)
    # if np.linalg.norm(params_reshape[i][0][0]-test_output[0][0]) <= 0.15:
        # append_index = append_index + 1
        # print(f'appended: {append_index}')
    predicted.append(test_output[0][0])
    simulated.append(params_reshape[i][0][0])
    # else:
    #     None
    
    # print(test_output, params_reshape[i])
# Out:
# 100%|██████████| 500/500 [00:25<00:00, 19.91it/s]

# %%
plt.figure(figsize=(16,8))
plt.plot([0,1], [0,1], 'red')
plt.scatter(simulated, predicted)
plt.xlabel('sigma simulated')
plt.ylabel('sigma predicted')
plt.title('Dense sigma prediction (pi/2)arctan((2/pi)X)')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Dense sigma prediction (pi/2)arctan((2/pi)X)')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
data = np.array([predicted, np.array(simulated).reshape(500, 1)]).reshape(2, 500)
pd.DataFrame(data).transpose().to_excel('arctan_dense_sigma_v1_preds.xlsx')

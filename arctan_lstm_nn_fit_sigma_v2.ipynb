# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
from tqdm import tqdm
import sklearn

# %%
print(sklearn.__version__)
# Out:
# 0.24.1

# %%
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
tf.config.experimental.set_visible_devices(devices=gpus[0], device_type='GPU')
tf.config.experimental.set_memory_growth(device=gpus[0], enable=True)

# %%
data = pd.read_csv('stoch_corr_arctan_1000_v2.csv', header=None)

# %%
observations = data.iloc[:100000, 1:1000]
paramsets = data.iloc[:100000, 1002:1003]

# %%
params_reshape = np.array(paramsets).reshape(100000, 1, 1)
one_sample_reshape = np.array(observations).reshape(100000,1,999)

# %%
print(params_reshape.shape, one_sample_reshape.shape)
# Out:
# (100000, 1, 1) (100000, 1, 999)

# %%
tf.keras.backend.clear_session()
tf.keras.backend.set_floatx('float64')

model = tf.keras.Sequential()
model.add(layer=tf.keras.layers.LSTM(units=16, return_sequences=True, input_shape=(1, 999)))
model.add(layer=tf.keras.layers.LSTM(units=16, return_sequences=True))
model.add(layer=tf.keras.layers.LSTM(units=16, return_sequences=True))
model.add(layer=tf.keras.layers.LSTM(units=16))
model.add(layer=tf.keras.layers.Dense(units=1, activation=tf.keras.activations.sigmoid))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 16)             65024
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 16)             2112
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 16)             2112
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 71,377
# Trainable params: 71,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer="adam",
    loss='mse',
)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10)

history = model.fit(x=one_sample_reshape, y=params_reshape, epochs=25, validation_split=0.20, batch_size=32, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/25
# 2500/2500 [==============================] - 40s 14ms/step - loss: 0.0330 - val_loss: 0.0150
# Epoch 2/25
# 2500/2500 [==============================] - 33s 13ms/step - loss: 0.0137 - val_loss: 0.0131
# Epoch 3/25
# 2500/2500 [==============================] - 32s 13ms/step - loss: 0.0109 - val_loss: 0.0116
# Epoch 4/25
# 2500/2500 [==============================] - 32s 13ms/step - loss: 0.0095 - val_loss: 0.0138
# Epoch 5/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0085 - val_loss: 0.0100
# Epoch 6/25
# 2500/2500 [==============================] - 29s 12ms/step - loss: 0.0078 - val_loss: 0.0096
# Epoch 7/25
# 2500/2500 [==============================] - 29s 12ms/step - loss: 0.0071 - val_loss: 0.0093
# Epoch 8/25
# 2500/2500 [==============================] - 29s 12ms/step - loss: 0.0065 - val_loss: 0.0089
# Epoch 9/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0062 - val_loss: 0.0097
# Epoch 10/25
# 2500/2500 [==============================] - 28s 11ms/step - loss: 0.0058 - val_loss: 0.0087
# Epoch 11/25
# 2500/2500 [==============================] - 29s 12ms/step - loss: 0.0055 - val_loss: 0.0086
# Epoch 12/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0052 - val_loss: 0.0087
# Epoch 13/25
# 2500/2500 [==============================] - 31s 12ms/step - loss: 0.0049 - val_loss: 0.0086
# Epoch 14/25
# 2500/2500 [==============================] - 29s 12ms/step - loss: 0.0048 - val_loss: 0.0085
# Epoch 15/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0047 - val_loss: 0.0086
# Epoch 16/25
# 2500/2500 [==============================] - 29s 12ms/step - loss: 0.0044 - val_loss: 0.0084
# Epoch 17/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0044 - val_loss: 0.0084
# Epoch 18/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0042 - val_loss: 0.0084
# Epoch 19/25
# 2500/2500 [==============================] - 31s 12ms/step - loss: 0.0041 - val_loss: 0.0082
# Epoch 20/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0039 - val_loss: 0.0083
# Epoch 21/25
# 2500/2500 [==============================] - 31s 12ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 22/25
# 2500/2500 [==============================] - 29s 12ms/step - loss: 0.0037 - val_loss: 0.0084
# Epoch 23/25
# 2500/2500 [==============================] - 30s 12ms/step - loss: 0.0035 - val_loss: 0.0085
# Epoch 24/25
# 2500/2500 [==============================] - 33s 13ms/step - loss: 0.0035 - val_loss: 0.0087
# Epoch 25/25
# 2500/2500 [==============================] - 29s 12ms/step - loss: 0.0034 - val_loss: 0.0085

# %%
simulated = []
predicted = []

append_index = 0
start = 90000

for i in tqdm(range(start, start + 500, 1)):
    test_input = one_sample_reshape[i]
    test_input_1 = test_input.reshape(1, 1, 999)
    test_output = model.predict(test_input_1, verbose=0)
    # if np.linalg.norm(params_reshape[i][0][0]-test_output[0][0]) <= 0.15:
        # append_index = append_index + 1
        # print(f'appended: {append_index}')
    predicted.append(test_output[0][0])
    simulated.append(params_reshape[i][0][0])
    # else:
    #     None
    
    # print(test_output, params_reshape[i])
# Out:
# 100%|██████████| 500/500 [00:24<00:00, 20.18it/s]

# %%
plt.figure(figsize=(16,8))
plt.plot([0,1], [0,1], 'red')
plt.scatter(simulated, predicted)
plt.xlabel('sigma simulated')
plt.ylabel('sigma predicted')
plt.title('LSTM sigma prediction (pi/2)arctan((2/pi)X)')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('LSTM sigma prediction (pi/2)arctan((2/pi)X) training curve')
plt.legend(['loss', 'val_loss'])
plt.show()
